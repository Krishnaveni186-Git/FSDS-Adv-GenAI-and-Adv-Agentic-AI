# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
i = 5
i
# Out:
# 5

# %%
type(i)
# Out:
# int

# %%
f = 110.34
f
# Out:
# 110.34

# %%
type(f)
# Out:
# float

# %% [markdown]
# # Boolean Datatype

# %% [markdown]
# # Boolean datatypes has only two possible values. i.e True or False

# %%
t = True
f = False
t+f
# Out:
# 1

# %%
print (t+f)
print(t-f)
print (t*f)
print (f/t)
# Out:
# 1
# 1
# 0
# 0.0

# %% [markdown]
# # Exponentional

# %% [markdown]
# # Exponential is a repeatation of multiplication

# %%
2e3
# Out:
# 2000.0

# %%
2e0
# Out:
# 2.0

# %%
2e2
# Out:
# 200.0

# %%
2e5
# Out:
# 200000.0

# %%
2.4e2
# Out:
# 240.0

# %%
4e3
# Out:
# 4000.0

# %%
-3e2
# Out:
# -300.0

# %% [markdown]
# # Complex datatype

# %% [markdown]
# # Complex datatype in python stores real and imaginary part.
# # Syntax = real + imaginary j

# %%
c =10 + 20j
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
type(c)
# Out:
# complex

# %%
c = 10 + 20j
d = 20 + 30j
print(c+d)
# Out:
# (30+50j)
