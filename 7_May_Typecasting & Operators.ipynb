# %% [markdown]
# # TypeCasting

# %% [markdown]
# # Its chnaging one datatype to another datatype.
#
# # There are 5 types of casting:
#
# 1. String
# 2. Flaot
# 3. Boolean
# 4. Complex
# 5. Integer

# %% [markdown]
# # Test Case 1

# %% [markdown]
# # Interger Typecasting: Its from other datatype to int & float except (complex, text string,user cannot pass more then 2 arguments/parameter)

# %%
int(4)
# Out:
# 4

# %%
int(3.0)
# Out:
# 3

# %%
int(True)
# Out:
# 1

# %%
int(10+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 int(10+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('20')

# %%
int(3.2,10.2) # Here you cant pass 2 arguments at a time

# %%
int(False)

# %%
int('5.2') # here chnaging float string to integer is not possible

# %% [markdown]
# # Test Case 2

# %%
float(4)

# %%
float(4.0)

# %%
float(True)

# %%
float(False)

# %%
float('10')

# %%
float(5+10j) # here infloat, complext cannot be chnaged to float

# %%
float('ten') # Text string is not coverted to float it shows value error

# %%
float(23.4)

# %% [markdown]
# # Test Case 3

# %%
# Boolean excepts all tyes of casting ie it converts all the types od data casting

# %%
bool('Ten')

# %%
bool(5)

# %%
bool(25.3)

# %%
bool(False)

# %%
bool(True)

# %%
bool(0)

# %%
bool()

# %%
bool(None)

# %% [markdown]
# # Test Case 4

# %% [markdown]
# # Complex Datatype : Here user cannot pass 2 argument as string, if user wants to pass string arg then it should be only 1 arg should be string

# %%
complex(10) # system considers 10 as real value

# %%
complex(10,20)

# %%
complex(True)

# %%
complex(False)

# %%
complex(True,False)

# %%
complex(False,False) # 0+0j =0

# %%
complex('10','25')  # Here complex cant take 2nd arg as string as 1st is already a string

# %%
complex(10,'20') # Here 2nd arg cant be a string

# %% [markdown]
# # Test Case 5
#
# # String : String can convert all types of datatypes (No Issue)

# %%
str(12)

# %%
str(True)

# %%
str('15')

# %%
str(10+5j)

# %%
str(False)

# %% [markdown]
# # Python Operator : Operators are symbols used to perform operations on values or variables.
#
# # There are 5 types of operatot:
#
# 1. Arithematic Operator
#
# 2. Relational Operator
#
# 3. Assignment Operator
#
# 4. Logical Operator
#
# 5. Unary Operator

# %% [markdown]
# # 1. Arithematic Operator

# %%
2+3 # addition operator

# %%
a = 15
b = 8
print(a)
print(b)

# %%
print(15+8)   #Addition
print (15-8)  #Substraction
print(5*6)    # Multiplication
print (8**2)  # Square
print(8/2)    #Division
print(8//2)   # Floor Division
print(a % b)  # Moudulas (Percentage)

# %%
(7**3)

# %%
(7***3) # Here cube will not work

# %%
print(a*2) # here a = 15 *2

# %% [markdown]
# # Assignment Operator: Used to assign values.

# %%
x = 2
x + 2 # Here its adds 2 to the x value i.e

# %%
x = 5
x += 2
x
# Out:
# 7

# %%
x = 5 
x -= 2
x
# Out:
# 3

# %%
x *= 3 # Here  it takes the lastest value of 'X'. 3 is multiplied 3 times 
x
# Out:
# 27

# %%
x /= 2
x
# Out:
# 6.75

# %%
x //= 2
x
# Out:
# 0.0

# %% [markdown]
# # 3. Relational Operator: Using operations for Camparing  [<,>,>=,<=,==, !=]

# %%
a = 5
b = 4
print (a,b)
# Out:
# 5 4

# %%
a < b
# Out:
# False

# %%
a > b
# Out:
# True

# %%
print (a >= b)
print (a <= b)
print (a == b)
print (a != b)
# Out:
# True
# False
# False
# True

# %% [markdown]
# # Logical Operator: its used to combine the conditions like AND = Both condition is true.  OR = Any one condition, NOT = Oppositive result

# %%
x = 10
y = 5
print (x,y)
# Out:
# 10 5

# %%
x < 5 and y < 3
# Out:
# False

# %%
x > 5 and y > 2
# Out:
# True

# %%
x < 12 and y < 45
# Out:
# True

# %%
x > 12 and y > 45
# Out:
# False

# %% [markdown]
# # Unary Operator: Unary means 1 . Its (-) Minus operator  it works on only 1 number.
