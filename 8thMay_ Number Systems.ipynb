# %% [markdown]
# # Number Systems: A number system is a way of writing and representing numbers using digits or symbols.
# # There are 4 types of number system. There are:
#
# # 1. Binary      ( Binary means 2 )
# # 2. Decimal     (Decimal means upto 10 (0-9))
# # 3. Octal       (Octal is 8 (0-7)
# # 4. Hexadecimal (Hexadecimal is 16 (0-9 , a-f))

# %%
# Binary: It means having 2 values i.e 0 & 1  (0b here b is base value (2))

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(12)
# Out:
# '0b1100'

# %%
bin(13)
# Out:
# '0b1101'

# %%
# Octal: It has value from 0-7 i.e assigned with 0o base value is 8

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
# Hexadecimal:  its base value is 16

# %%
hex(25)
# Out:
# '0x19'

# %%
hex(35)
# Out:
# '0x23'

# %%
hex(1)
# Out:
# '0x1'

# %%
hex(16)
# Out:
# '0x10'
